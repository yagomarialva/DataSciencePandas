# %% [markdown]
# # Relatório de Análise I

# %% [markdown]
# ## Importando a base de dados

# %%
import pandas as pd

# %%
pd.read_csv('dados/HIST_PAINEL_COVIDBR_19jan2021.csv', sep = ';')
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 1680946  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680947  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680948  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680949  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680950  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
dados = pd.read_csv('dados/HIST_PAINEL_COVIDBR_19jan2021.csv', sep = ';')

# %%
dados
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 1680946  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680947  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680948  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680949  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680950  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.info
# Out:
# <bound method DataFrame.info of                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 1680946  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680947  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680948  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680949  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1680950  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1680951 entries, 0 to 1680950
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   regiao                  1680951 non-null  object
#  1   estado                  1680619 non-null  object
#  2   municipio               1665430 non-null  object
#  3   coduf                   1680951 non-null  int64
#  4   codmun                  1671709 non-null  float64
#  5   codRegiaoSaude          1665430 non-null  float64
#  6   nomeRegiaoSaude         1665430 non-null  object
#  7   data                    1680951 non-null  object
#  8   semanaEpi               1680951 non-null  int64
#  9   populacaoTCU2019        1674672 non-null  float64
#  10  casosAcumulado          1680951 non-null  int64
#  11  casosNovos              1680951 non-null  int64
#  12  obitosAcumulado         1680951 non-null  int64
# ...

# %%
dados.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-25          9       210147125.0               0           0
# 1  2020-02-26          9       210147125.0               1           1
# 2  2020-02-27          9       210147125.0               1           0
# 3  2020-02-28          9       210147125.0               1           0
# 4  2020-02-29          9       210147125.0               2           1
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %% [markdown]
# ## Informações gerais sobre a Base de Dados

# %%
dados.dtypes
# Out:
# regiao                     object
# estado                     object
# municipio                  object
# coduf                       int64
# codmun                    float64
# codRegiaoSaude            float64
# nomeRegiaoSaude            object
# data                       object
# semanaEpi                   int64
# populacaoTCU2019          float64
# casosAcumulado              int64
# casosNovos                  int64
# obitosAcumulado             int64
# obitosNovos                 int64
# Recuperadosnovos          float64
# emAcompanhamentoNovos     float64
# interior/metropolitana    float64
# dtype: object

# %%
pd.DataFrame(dados.dtypes, columns = ['Tipos de Dados'])
# Out:
#                        Tipos de Dados
# regiao                         object
# estado                         object
# municipio                      object
# coduf                           int64
# codmun                        float64
# codRegiaoSaude                float64
# nomeRegiaoSaude                object
# data                           object
# semanaEpi                       int64
# populacaoTCU2019              float64
# casosAcumulado                  int64
# casosNovos                      int64
# obitosAcumulado                 int64
# obitosNovos                     int64
# Recuperadosnovos              float64
# emAcompanhamentoNovos         float64
# interior/metropolitana        float64

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns = ['Tipos de Dados'])

# %%
tipos_de_dados.columns.name = 'Variáveis'

# %%
tipos_de_dados
# Out:
# Variáveis              Tipos de Dados
# regiao                         object
# estado                         object
# municipio                      object
# coduf                           int64
# codmun                        float64
# codRegiaoSaude                float64
# nomeRegiaoSaude                object
# data                           object
# semanaEpi                       int64
# populacaoTCU2019              float64
# casosAcumulado                  int64
# casosNovos                      int64
# obitosAcumulado                 int64
# obitosNovos                     int64
# Recuperadosnovos              float64
# emAcompanhamentoNovos         float64
# interior/metropolitana        float64

# %%
dados.shape
# Out:
# (1680951, 17)

# %%
dados.shape[0]
# Out:
# 1680951

# %%
dados.shape[1]
# Out:
# 17

# %%
print('A base de Dados apresenta {} registros (casos) e {} variáveis'.format(dados.shape[0], dados.shape[1]))
# Out:
# A base de Dados apresenta 1680951 registros (casos) e 17 variáveis
